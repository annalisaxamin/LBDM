# %%
import pandas as pd

# %%
df = pd.read_csv("./dataset/GSE45827.top.table.tsv", sep="\t")
df.head()
# Out:
#             ID     adj.P.Val       P.Value         F  \
# 0    211565_at  1.380000e-85  4.610000e-90  677.6179
# 1  243689_s_at  1.020000e-67  6.810000e-72  355.1811
# 2   1562755_at  5.090000e-64  5.120000e-68  308.1276
# 3   1561754_at  3.920000e-60  5.250000e-64  265.3890
# 4    224012_at  5.650000e-58  9.460000e-62  243.7328
#
#                                      Gene.symbol  \
# 0                                         SH3GL3
# 1                                         FRG1BP
# 2                                            NaN
# 3                                            NaN
# 4  ANKRD20A4///ANKRD20A2///ANKRD20A3///ANKRD20A1
#
#                                           Gene.title  \
# 0   SH3 domain containing GRB2 like 3, endophilin A3
# 1     FSHD region gene 1 family member B, pseudogene
# 2                                                NaN
# 3                                                NaN
# 4  ankyrin repeat domain 20 family member A4///an...
#
#                             Gene.ID           Chromosome.location  \
# 0                              6457                         15q24
# 1                            284802                      20q11.21
# 2                               NaN                           NaN
# 3                               NaN                           NaN
# 4  728747///441430///441425///84210  9q21.11///9p12///9p12///9q13
#
#                                Chromosome.annotation  \
# 0   Chromosome 15, NC_000015.10 (83447123..83618743)
# 1   Chromosome 20, NC_000020.11 (30377203..30399331)
# 2                                                NaN
# 3                                                NaN
# 4  Chromosome 9, NC_000009.12 (64369563..64412691...
#
#                            UniGene.title  ... GenBank.Accession  \
# 0                                    NaN  ...          AF036272
# 1                                    NaN  ...          AI681945
# 2               CDNA clone IMAGE:5286775  ...          BC043419
# 3  Full length insert cDNA clone ZA88B06  ...          AF086134
# 4                                    NaN  ...          AL136793
#
#   Platform_CLONEID Platform_ORF  Platform_SPOTID  \
# 0              NaN          NaN              NaN
# 1              NaN          NaN              NaN
# 2              NaN          NaN              NaN
# 3              NaN          NaN              NaN
# 4              NaN          NaN              NaN
#
#                                          GO.Function  \
# 0  identical protein binding///lipid binding///pr...
# 1                             actin filament binding
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           GO.Process  \
# 0  central nervous system development///endocytos...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         GO.Component  \
# 0    early endosome membrane///extracellular exosome
# 1  catalytic step 2 spliceosome///nucleolus///str...
# 2                                                NaN
# 3                                                NaN
# 4                                    plasma membrane
#
#                          GO.Function.ID                         GO.Process.ID  \
# 0  GO:0042802///GO:0008289///GO:0005515  GO:0007417///GO:0006897///GO:0007165
# 1                            GO:0051015                                   NaN
# 2                                   NaN                                   NaN
# 3                                   NaN                                   NaN
# 4                                   NaN                                   NaN
#
#                         GO.Component.ID
# 0               GO:0031901///GO:0070062
# 1  GO:0071013///GO:0005730///GO:0055120
# 2                                   NaN
# 3                                   NaN
# 4                            GO:0005886
#
# [5 rows x 24 columns]

# %%
genes_of_interest = {"SNORA1","SNORA12","SNORA14B","SNORA16A","SNORA21","SNORA23","SNORA24","SNORA32","SNORA38","SNORA44","SNORA48","SNORA49","SNORA52","SNORA53","SNORA57","SNORA61","SNORA63","SNORA64","SNORA65","SNORA70","SNORA71C","SNORA73A","SNORA73B","SNORA75","SNORA78","SNORA8","SNORD10","SNORD102","SNORD104","SNORD105","SNORD105B","SNORD108","SNORD110","SNORD111B","SNORD113-3","SNORD113-4","SNORD114-1","SNORD114-13","SNORD114-14","SNORD114-19","SNORD114-20","SNORD114-21","SNORD115-23","SNORD115-32","SNORD116-13","SNORD119","SNORD12","SNORD12B","SNORD13","SNORD14A","SNORD14C","SNORD14D","SNORD15B","SNORD16","SNORD17","SNORD18A","SNORD1B","SNORD20","SNORD22","SNORD26","SNORD28","SNORD29","SNORD32A","SNORD33","SNORD34","SNORD35A","SNORD36A","SNORD36B","SNORD38A","SNORD3A","SNORD3D","SNORD41","SNORD42A","SNORD42B","SNORD44","SNORD45A","SNORD47","SNORD49B","SNORD4B","SNORD5","SNORD50A","SNORD52","SNORD53","SNORD54","SNORD55","SNORD56","SNORD57","SNORD58A","SNORD58C","SNORD59A","SNORD60","SNORD63","SNORD64","SNORD65","SNORD68","SNORD69","SNORD71","SNORD74","SNORD76","SNORD8","SNORD81","SNORD82","SNORD84","SNORD86","SNORD87","SNORD89","SNORD94","SNORD96A","SNORD97","SNORD99","TMX1","ZFAS1","CDKN2B-AS1","CWF19L1","EIF4A1","EP400","HIF1A-AS2","MEG8","NOP56","RACK1","RPL13A","RPS13","SCARNA12","SNHG12","SNHG20","SNHG5","SNHG6","SNHG7","SNHG8","AP1G1","CFDP1","CHD8","DDX39B","EEF2","EIF4A2","EIF4G2","GAS5","GNL3","HSPA8","HSPA9","IPO7","MYRIP","NAN","NCL","NFATC3","PCAT4","PPAN","PRKAA1","PRRC2A","PTCD3","RABGGTB","RNF149","RPL10","RPL12","RPL13","RPL17","RPL21","RPL23","RPL23A","RPL4","RPL7A","RPLP2","RPS11","RPS2","RPS20","RPS3","RPS8","SF3B3","SLC25A3","SNHG1","SNHG3","SNHG9","SNORD1C","SNORD35B","SNORD37","SNRPB","SNX5","TAF1D","TNPO2","TOMM20","WDR43"}
df = df[df["Gene.symbol"].isin(genes_of_interest)]
df.head()
# Out:
#                ID     adj.P.Val       P.Value        F Gene.symbol  \
# 272     213350_at  5.870000e-33  5.370000e-35  79.6520       RPS11
# 1174  213175_s_at  6.340000e-24  2.490000e-25  48.0864       SNRPB
# 2429  200692_s_at  3.100000e-19  2.520000e-20  35.2907       HSPA9
# 2543    200993_at  6.610000e-19  5.630000e-20  34.4737        IPO7
# 2730    225141_at  1.910000e-18  1.750000e-19  33.3388      NFATC3
#
#                                              Gene.title Gene.ID  \
# 272                               ribosomal protein S11    6205
# 1174  small nuclear ribonucleoprotein polypeptides B...    6628
# 2429       heat shock protein family A (Hsp70) member 9    3313
# 2543                                         importin 7   10527
# 2730              nuclear factor of activated T-cells 3    4775
#
#      Chromosome.location                              Chromosome.annotation  \
# 272              19q13.3   Chromosome 19, NC_000019.10 (49496365..49499712)
# 1174               20p13  Chromosome 20, NC_000020.11 (2461635..2470853,...
# 2429              5q31.1  Chromosome 5, NC_000005.10 (138554882..1385756...
# 2543             11p15.4     Chromosome 11, NC_000011.10 (9384622..9448127)
# 2730             16q22.2   Chromosome 16, NC_000016.10 (68085366..68229259)
#
#      UniGene.title  ... GenBank.Accession Platform_CLONEID Platform_ORF  \
# 272            NaN  ...          BF680255              NaN          NaN
# 1174           NaN  ...               NaN              NaN          NaN
# 2429           NaN  ...         NM_004134              NaN          NaN
# 2543           NaN  ...          AA939270              NaN          NaN
# 2730           NaN  ...          AW298438              NaN          NaN
#
#       Platform_SPOTID                                        GO.Function  \
# 272               NaN  poly(A) RNA binding///protein binding///rRNA b...
# 1174              NaN  U2 snRNA binding///histone pre-mRNA DCP bindin...
# 2429              NaN  ATP binding///fibroblast growth factor binding...
# 2543              NaN  GTPase regulator activity///Ran GTPase binding...
# 2730              NaN  RNA polymerase II core promoter proximal regio...
#
#                                              GO.Process  \
# 272   SRP-dependent cotranslational protein targetin...
# 1174  RNA splicing///histone mRNA metabolic process/...
# 2429  cellular response to interleukin-1///erythrocy...
# 2543  innate immune response///protein import into n...
# 2730  Fc-epsilon receptor signaling pathway///inflam...
#
#                                            GO.Component  \
# 272   cytoplasm///cytosol///cytosolic small ribosoma...
# 1174  SMN-Sm protein complex///U1 snRNP///U12-type s...
# 2429  cytoplasm///extracellular exosome///extracellu...
# 2543  cytoplasm///cytosol///membrane///nuclear pore/...
# 2730  cytoplasm///cytosol///nucleolus///nucleoplasm/...
#
#                                          GO.Function.ID  \
# 272   GO:0044822///GO:0005515///GO:0019843///GO:0003735
# 1174  GO:0030620///GO:0071208///GO:0044822///GO:0005...
# 2429  GO:0005524///GO:0017134///GO:0031072///GO:0044...
# 2543  GO:0030695///GO:0008536///GO:0046332///GO:0042...
# 2730  GO:0000978///GO:0005515///GO:0001077///GO:0001...
#
#                                           GO.Process.ID  \
# 272   GO:0006614///GO:0000184///GO:0001649///GO:0006...
# 1174  GO:0008380///GO:0008334///GO:0000398///GO:0000...
# 2429  GO:0071347///GO:0030218///GO:0043066///GO:0045...
# 2543  GO:0045087///GO:0006606///GO:0050790///GO:0007...
# 2730  GO:0038095///GO:0006954///GO:1902894///GO:0045...
#
#                                         GO.Component.ID
# 272   GO:0005737///GO:0005829///GO:0022627///GO:0070...
# 1174  GO:0034719///GO:0005685///GO:0005689///GO:0005...
# 2429  GO:0005737///GO:0070062///GO:0031012///GO:0005...
# 2543  GO:0005737///GO:0005829///GO:0016020///GO:0005...
# 2730  GO:0005737///GO:0005829///GO:0005730///GO:0005...
#
# [5 rows x 24 columns]

# %%
df.to_csv("./dataset/GSE45827.top.table.filtered.tsv", sep="\t", index=False)

# %%
df.columns
# Out:
# Index(['ID', 'adj.P.Val', 'P.Value', 'F', 'Gene.symbol', 'Gene.title',
#        'Gene.ID', 'Chromosome.location', 'Chromosome.annotation',
#        'UniGene.title', 'UniGene.symbol', 'UniGene.ID', 'Nucleotide.Title',
#        'GI', 'GenBank.Accession', 'Platform_CLONEID', 'Platform_ORF',
#        'Platform_SPOTID', 'GO.Function', 'GO.Process', 'GO.Component',
#        'GO.Function.ID', 'GO.Process.ID', 'GO.Component.ID'],
#       dtype='object')
