# %%
import pandas as pd

# %%
expression_matrix = pd.read_csv("../R_code/exp_matrix_cancer.csv")
expression_matrix.drop(['Unnamed: 0'], axis=1, inplace=True)
expression_matrix.head(5)
# Out:
#    1007_s_at   1053_at    117_at    121_at  1255_g_at   1294_at   1316_at  \
# 0   8.496339  5.944231  5.838808  7.180569   2.759084  7.383376  7.096457
# 1   7.354706  5.633305  6.325852  7.901653   4.077464  7.294313  6.295099
# 2   6.898585  5.871544  5.514367  7.718790   3.175172  8.083949  5.853364
# 3   9.640469  5.893211  5.668953  7.640794   3.067836  7.310535  6.694541
# 4   8.175582  6.151961  6.065677  7.563042   2.980283  7.557248  7.165543
#
#     1320_at  1405_i_at   1431_at  ...  AFFX-r2-P1-cre-3_at  \
# 0  4.803199   6.957270  3.321985  ...            13.985169
# 1  4.436363   6.889800  3.972205  ...            14.241674
# 2  4.366101   5.378046  3.347600  ...            14.205027
# 3  4.268436   5.611767  3.496480  ...            14.348157
# 4  4.727182   5.927592  3.372731  ...            14.126333
#
#    AFFX-r2-P1-cre-5_at  AFFX-ThrX-3_at  AFFX-ThrX-5_at  AFFX-ThrX-M_at  \
# 0            13.774519        9.948910        6.152068        8.171463
# 1            14.060209       13.450387       10.559453       12.546760
# 2            14.096933       13.243120       10.395400       12.455792
# 3            14.244256       11.973984        7.766641       10.270549
# 4            13.988384       10.456795        6.946789        8.623066
#
#    AFFX-TrpnX-3_at  AFFX-TrpnX-5_at  AFFX-TrpnX-M_at  \
# 0         2.693050         3.063041         3.117905
# 1         2.702545         3.845348         3.677584
# 2         2.722887         3.705345         3.173042
# 3         2.867993         3.215214         3.420670
# 4         2.770782         3.170171         3.164002
#
#                  sample_names  has_cancer
# 0  GSM1045191_N1_15_12_04.CEL           0
# 1  GSM1045192_N4_14_12_04.CEL           0
# 2  GSM1045193_N5_15_12_04.CEL           0
# 3  GSM1045194_N6_14_12_04.CEL           0
# 4  GSM1045195_P1_15_12_04.CEL           0
#
# [5 rows x 54677 columns]

# %%
annotation = pd.read_csv("../R_code/annotation.csv", encoding='utf-8')
annotation.head(5)
# Out:
#    ensembl_gene_id affy_hg_u133_plus_2 hgnc_symbol  \
# 0  ENSG00000198888        1553551_s_at      MT-ND1
# 1  ENSG00000210100        1553551_s_at       MT-TI
# 2  ENSG00000210112        1553551_s_at       MT-TM
# 3  ENSG00000198763        1553551_s_at      MT-ND2
# 4  ENSG00000198804        1553538_s_at      MT-CO1
#
#                                          description refseq_mrna refseq_ncrna
# 0  mitochondrially encoded NADH:ubiquinone oxidor...         NaN          NaN
# 1  mitochondrially encoded tRNA-Ile (AUU/C) [Sour...         NaN          NaN
# 2  mitochondrially encoded tRNA-Met (AUA/G) [Sour...         NaN          NaN
# 3  mitochondrially encoded NADH:ubiquinone oxidor...         NaN          NaN
# 4  mitochondrially encoded cytochrome c oxidase I...         NaN          NaN

# %%
annotation[annotation['affy_hg_u133_plus_2'] == '1007_s_at']
# Out:
#       ensembl_gene_id affy_hg_u133_plus_2 hgnc_symbol  \
# 477   ENSG00000234078           1007_s_at        DDR1
# 478   ENSG00000234078           1007_s_at        DDR1
# 479   ENSG00000234078           1007_s_at        DDR1
# 480   ENSG00000234078           1007_s_at        DDR1
# 481   ENSG00000234078           1007_s_at        DDR1
# ...               ...                 ...         ...
# 6284  ENSG00000204580           1007_s_at        DDR1
# 6285  ENSG00000204580           1007_s_at        DDR1
# 6286  ENSG00000204580           1007_s_at        DDR1
# 6287  ENSG00000204580           1007_s_at        DDR1
# 6288  ENSG00000204580           1007_s_at        DDR1
#
#                                             description   refseq_mrna  \
# 477   discoidin domain receptor tyrosine kinase 1 [S...  NM_001387915
# 478   discoidin domain receptor tyrosine kinase 1 [S...  NM_001387917
# 479   discoidin domain receptor tyrosine kinase 1 [S...     NM_001954
# 480   discoidin domain receptor tyrosine kinase 1 [S...  NM_001387916
# 481   discoidin domain receptor tyrosine kinase 1 [S...  NM_001387918
# ...                                                 ...           ...
# 6284  discoidin domain receptor tyrosine kinase 1 [S...  NM_001387911
# 6285  discoidin domain receptor tyrosine kinase 1 [S...  NM_001387912
# 6286  discoidin domain receptor tyrosine kinase 1 [S...  NM_001202523
# 6287  discoidin domain receptor tyrosine kinase 1 [S...  NM_001202521
# 6288  discoidin domain receptor tyrosine kinase 1 [S...  NM_001202522
#
#      refseq_ncrna
# 477           NaN
# 478           NaN
# 479           NaN
# 480           NaN
# 481           NaN
# ...           ...
# 6284          NaN
# 6285          NaN
# 6286          NaN
# 6287          NaN
# 6288          NaN
#
# [183 rows x 6 columns]

# %%
expression_matrix.columns.unique()
# Out:
# Index(['1007_s_at', '1053_at', '117_at', '121_at', '1255_g_at', '1294_at',
#        '1316_at', '1320_at', '1405_i_at', '1431_at',
#        ...
#        'AFFX-r2-P1-cre-3_at', 'AFFX-r2-P1-cre-5_at', 'AFFX-ThrX-3_at',
#        'AFFX-ThrX-5_at', 'AFFX-ThrX-M_at', 'AFFX-TrpnX-3_at',
#        'AFFX-TrpnX-5_at', 'AFFX-TrpnX-M_at', 'sample_names', 'has_cancer'],
#       dtype='object', length=54677)
