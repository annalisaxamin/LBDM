# %%
import pandas as pd
import re

# %% [markdown]
# # Preparation of the datasets

# %% [markdown]
# We read the csv containing the FANTOM's annotations and we generate a dataframe.

# %%
df = pd.read_csv("anno-fantom.csv") #dataframe with FANTOM annotations

# %%
df
# Out:
#        T000001           p1@LOXL4          84171        17171  \
# 0      T000006         p1@PYROXD2          84795        23517
# 1      T000007         p2@PYROXD2          84795        23517
# 2      T000014            p1@HPS1           3257         5163
# 3      T000023           p1@HPSE2          60495        18374
# 4      T000024           p3@HPSE2          60495        18374
# ...        ...                ...            ...          ...
# 87548  T201777            p1@PRKY           5616         9444
# 87549  T201778            p4@PRKY           5616         9444
# 87550  T201779            p3@PRKY            NaN         9444
# 87551  T201797  p1@TSPY4,p1@TSPY8  728403,728395  37471,37287
# 87552  T201798         p2@RPL14P5            NaN        37720
#
#                                    Q96JB6    LOXL4  \
# 0                                  Q8N2H3  PYROXD2
# 1                                  Q8N2H3  PYROXD2
# 2                    Q92902,Q658M9,Q8WXE5     HPS1
# 3                                  Q8WWQ2    HPSE2
# 4                                  Q8WWQ2    HPSE2
# ...                                   ...      ...
# 87548                                 NaN     PRKY
# 87549                                 NaN     PRKY
# 87550                              O43930     PRKY
# 87551  F8VZD1,A6NGL4,P0CV99,P0CW00,P0CW01    TSPY8
# 87552                                 NaN  RPL14P5
#
#                                     lysyl oxidase like 4  \
# 0      pyridine nucleotide-disulphide oxidoreductase ...
# 1      pyridine nucleotide-disulphide oxidoreductase ...
# 2      HPS1, biogenesis of lysosomal organelles compl...
# 3                                heparanase 2 (inactive)
# 4                                heparanase 2 (inactive)
# ...                                                  ...
# 87548               protein kinase, Y-linked, pseudogene
# 87549               protein kinase, Y-linked, pseudogene
# 87550               protein kinase, Y-linked, pseudogene
# 87551                testis specific protein, Y-linked 8
# 87552                 ribosomal protein L14 pseudogene 5
#
#        gene with protein product
# 0      gene with protein product
# 1      gene with protein product
# 2      gene with protein product
# 3      gene with protein product
# 4      gene with protein product
# ...                          ...
# 87548                 pseudogene
# 87549                 pseudogene
# 87550                 pseudogene
# 87551  gene with protein product
# 87552                 pseudogene
#
# [87553 rows x 8 columns]

# %% [markdown]
# The file appears to be without a header. We simply rewrite the column names because we don't need the first line.

# %%
df.rename(columns={'T000001':'id', 'p1@LOXL4':'gene', '84171':'n1', '17171':'n2', 'Q96JB6':'n3', 'LOXL4':'n4', 'lysyl oxidase like 4':'descrizione1', 'gene with protein product':'descrizione2'}, inplace=True)
df.set_index('id', inplace=True)

# %% [markdown]
# In order to find snoRNAs, we filter te dataframe. Then, we create another dataframe with just the entries that correspond to the small nucleolar RNA.

# %%
# These two transformations are used to avoid errors in the for loops
df['descrizione2']=df['descrizione2'].apply(str)
df['descrizione1']=df['descrizione1'].apply(str)

regexp = re.compile(r'.RNA, small nucleolar.') # We only search for rows that contain this text in the last column
toKeep = []

for index, row in df.iterrows():
    if regexp.search(row.descrizione2):
        toKeep.append(row)

regexp = re.compile(r'small nucleolar RNA.') # We only search for rows that contain this text in the second last column
for index, row in df.iterrows():
    if regexp.search(row.descrizione1):
        toKeep.append(row)

df2 = pd.DataFrame(toKeep) 
df2
# Out:
#                 gene      n1     n2   n3        n4  \
# T000102   p1@SNORA12  677800  32600  NaN   SNORA12
# T009375   p2@SNORD97  692223  32760  NaN   SNORD97
# T009376   p4@SNORD97  692223  32760  NaN   SNORD97
# T009377   p1@SNORD97  692223  32760  NaN   SNORD97
# T009378   p3@SNORD97  692223  32760  NaN   SNORD97
# ...              ...     ...    ...  ...       ...
# T189749   p1@SNORA65   26783  10222  NaN   SNORA65
# T190879  p2@SNORD36B     NaN  10164  NaN  SNORD36B
# T190880  p1@SNORD36A   26815  10163  NaN  SNORD36A
# T191363     p1@SNHG7   84973  28254  NaN     SNHG7
# T198431   p2@SNORA70   26778  10231  NaN   SNORA70
#
#                               descrizione1          descrizione2
# T000102  small nucleolar RNA, H/ACA box 12  RNA, small nucleolar
# T009375    small nucleolar RNA, C/D box 97  RNA, small nucleolar
# T009376    small nucleolar RNA, C/D box 97  RNA, small nucleolar
# T009377    small nucleolar RNA, C/D box 97  RNA, small nucleolar
# T009378    small nucleolar RNA, C/D box 97  RNA, small nucleolar
# ...                                    ...                   ...
# T189749  small nucleolar RNA, H/ACA box 65  RNA, small nucleolar
# T190879   small nucleolar RNA, C/D box 36B  RNA, small nucleolar
# T190880   small nucleolar RNA, C/D box 36A  RNA, small nucleolar
# T191363    small nucleolar RNA host gene 7  RNA, long non-coding
# T198431  small nucleolar RNA, H/ACA box 70  RNA, small nucleolar
#
# [186 rows x 7 columns]

# %% [markdown]
# We can now save the newly created dataset as a csv.

# %%
df2.to_csv('anno-fantom-sno.csv', index_label='id', encoding='utf-8')

# %% [markdown]
# Now we read the second dataset, which has the annotation for the expansion, and repeat the search for the required rows, using the same regexes.

# %%
df3 = pd.read_csv("expansion_annotation.tsv", sep="\t", encoding='utf-8')
df3.head(5)
# Out:
#   hgnc_id_first                 X00Annotation short_description  \
# 0    HGNC:17171  chr10:100027943..100027958,-          p1@LOXL4
# 1    HGNC:23517  chr10:100174900..100174956,-        p1@PYROXD2
# 2    HGNC:23517  chr10:100174957..100174982,-        p2@PYROXD2
# 3     HGNC:5163  chr10:100206642..100206717,-           p1@HPS1
# 4    HGNC:18374  chr10:100995440..100995474,-          p1@HPSE2
#
#                    description  \
# 0    CAGE_peak_1_at_LOXL4_5end
# 1  CAGE_peak_1_at_PYROXD2_5end
# 2  CAGE_peak_2_at_PYROXD2_5end
# 3     CAGE_peak_1_at_HPS1_5end
# 4    CAGE_peak_1_at_HPSE2_5end
#
#                          association_with_transcript     entrezgene_id  \
# 0  48bp_to_ENST00000260702,NM_032211,uc001kpa.1_5end  entrezgene:84171
# 1        0bp_to_ENST00000370575,ENST00000462874_5end  entrezgene:84795
# 2  0bp_to_NM_032709,uc001kpc.2,uc001kpd.2,uc010qp...  entrezgene:84795
# 3  0bp_to_ENST00000325103,ENST00000338546,ENST000...   entrezgene:3257
# 4                              84bp_to_AJ299720_5end  entrezgene:60495
#
#       hgnc_id                                    uniprot_id   symbol  \
# 0  HGNC:17171                                uniprot:Q96JB6    LOXL4
# 1  HGNC:23517                                uniprot:Q8N2H3  PYROXD2
# 2  HGNC:23517                                uniprot:Q8N2H3  PYROXD2
# 3   HGNC:5163  uniprot:Q92902,uniprot:Q658M9,uniprot:Q8WXE5     HPS1
# 4  HGNC:18374                                uniprot:Q8WWQ2    HPSE2
#
#                                                 name  \
# 0                               lysyl oxidase like 4
# 1  pyridine nucleotide-disulphide oxidoreductase ...
# 2  pyridine nucleotide-disulphide oxidoreductase ...
# 3  HPS1, biogenesis of lysosomal organelles compl...
# 4                            heparanase 2 (inactive)
#
#                   locus_type omim_id lncrnadb      TID  \
# 0  gene with protein product  607318      NaN  T000001
# 1  gene with protein product     NaN      NaN  T000006
# 2  gene with protein product     NaN      NaN  T000007
# 3  gene with protein product  604982      NaN  T000014
# 4  gene with protein product  613469      NaN  T000023
#
#                             CID
# 0  chr10:100027943..100027958,-
# 1  chr10:100174900..100174956,-
# 2  chr10:100174957..100174982,-
# 3  chr10:100206642..100206717,-
# 4  chr10:100995440..100995474,-

# %%
# Again, we apply the type transformation to avoid errors in the for loops
df3['locus_type']=df3['locus_type'].apply(str)
df3['name']=df3['name'].apply(str)

# The regexes are the same as before
regexp = re.compile(r'.RNA, small nucleolar.')
toKeep = []

for index, row in df3.iterrows():
    if regexp.search(row["locus_type"]):
        toKeep.append(row)

regexp = re.compile(r'small nucleolar RNA.')
for index, row in df3.iterrows():
    if regexp.search(row["name"]):
        toKeep.append(row)

df3 = pd.DataFrame(toKeep)
df3.head(5)
# Out:
#      hgnc_id_first                 X00Annotation short_description  \
# 54      HGNC:32600  chr10:101997055..101997059,-        p1@SNORA12
# 3805    HGNC:32760    chr11:10823145..10823156,-        p2@SNORD97
# 3806    HGNC:32760    chr11:10823282..10823289,-        p4@SNORD97
# 3807    HGNC:32760    chr11:10823311..10823327,-        p1@SNORD97
# 3808    HGNC:32760    chr11:10823646..10823666,-        p3@SNORD97
#
#                       description  \
# 54    CAGE_peak_1_at_SNORA12_5end
# 3805  CAGE_peak_2_at_SNORD97_5end
# 3806  CAGE_peak_4_at_SNORD97_5end
# 3807  CAGE_peak_1_at_SNORD97_5end
# 3808  CAGE_peak_3_at_SNORD97_5end
#
#                            association_with_transcript      entrezgene_id  \
# 54    0bp_to_ENST00000391162,NR_002954,uc001kqu.1_5end  entrezgene:677800
# 3805  0bp_to_ENST00000459187,NR_004403,uc009yge.2_5end  entrezgene:692223
# 3806               -127bp_to_NR_004403,uc009yge.2_5end  entrezgene:692223
# 3807               -156bp_to_NR_004403,uc009yge.2_5end  entrezgene:692223
# 3808               -491bp_to_NR_004403,uc009yge.2_5end  entrezgene:692223
#
#          hgnc_id uniprot_id   symbol                               name  \
# 54    HGNC:32600        NaN  SNORA12  small nucleolar RNA, H/ACA box 12
# 3805  HGNC:32760        NaN  SNORD97    small nucleolar RNA, C/D box 97
# 3806  HGNC:32760        NaN  SNORD97    small nucleolar RNA, C/D box 97
# 3807  HGNC:32760        NaN  SNORD97    small nucleolar RNA, C/D box 97
# 3808  HGNC:32760        NaN  SNORD97    small nucleolar RNA, C/D box 97
#
#                 locus_type omim_id lncrnadb      TID  \
# 54    RNA, small nucleolar  611330      NaN  T000102
# 3805  RNA, small nucleolar     NaN      NaN  T009375
# 3806  RNA, small nucleolar     NaN      NaN  T009376
# 3807  RNA, small nucleolar     NaN      NaN  T009377
# 3808  RNA, small nucleolar     NaN      NaN  T009378
#
#                                CID
# 54    chr10:101997055..101997059,-
# 3805    chr11:10823145..10823156,-
# 3806    chr11:10823282..10823289,-
# 3807    chr11:10823311..10823327,-
# 3808    chr11:10823646..10823666,-

# %% [markdown]
# As before, we save this new dataset as csv.

# %%
#df3.set_index('hgnc_id_first', inplace=True)
df3.to_csv("expansion_annotation_sno.csv", index_label='id', encoding='utf-8')

# %% [markdown]
# We add a new column which contains the gene name to the previous dataframe (df2- filtered dataset of FANTOM annotation). Later on, it will be useful.

# %%
df2['gene_name'] = df2['gene'].apply(lambda x: re.sub(r'..@', "", x, count=0, flags=0))
df2
# Out:
#                 gene      n1     n2   n3        n4  \
# T000102   p1@SNORA12  677800  32600  NaN   SNORA12
# T009375   p2@SNORD97  692223  32760  NaN   SNORD97
# T009376   p4@SNORD97  692223  32760  NaN   SNORD97
# T009377   p1@SNORD97  692223  32760  NaN   SNORD97
# T009378   p3@SNORD97  692223  32760  NaN   SNORD97
# ...              ...     ...    ...  ...       ...
# T189749   p1@SNORA65   26783  10222  NaN   SNORA65
# T190879  p2@SNORD36B     NaN  10164  NaN  SNORD36B
# T190880  p1@SNORD36A   26815  10163  NaN  SNORD36A
# T191363     p1@SNHG7   84973  28254  NaN     SNHG7
# T198431   p2@SNORA70   26778  10231  NaN   SNORA70
#
#                               descrizione1          descrizione2 gene_name
# T000102  small nucleolar RNA, H/ACA box 12  RNA, small nucleolar   SNORA12
# T009375    small nucleolar RNA, C/D box 97  RNA, small nucleolar   SNORD97
# T009376    small nucleolar RNA, C/D box 97  RNA, small nucleolar   SNORD97
# T009377    small nucleolar RNA, C/D box 97  RNA, small nucleolar   SNORD97
# T009378    small nucleolar RNA, C/D box 97  RNA, small nucleolar   SNORD97
# ...                                    ...                   ...       ...
# T189749  small nucleolar RNA, H/ACA box 65  RNA, small nucleolar   SNORA65
# T190879   small nucleolar RNA, C/D box 36B  RNA, small nucleolar  SNORD36B
# T190880   small nucleolar RNA, C/D box 36A  RNA, small nucleolar  SNORD36A
# T191363    small nucleolar RNA host gene 7  RNA, long non-coding     SNHG7
# T198431  small nucleolar RNA, H/ACA box 70  RNA, small nucleolar   SNORA70
#
# [186 rows x 8 columns]

# %% [markdown]
# We read the dataset for the snoDB version 2 and visualize the content. We save its content into another dataframe (df4).

# %%
df4 = pd.read_csv("snoDB_All_V2.0.tsv", sep="\t", encoding='utf-8') #dataset snoDB v.2
df4
# Out:
#        snodb_id       ensembl_id    refseq_id     hgnc_id      ncbi_id  \
# 0     snoDB0001  ENSG00000221083          NaN         NaN          NaN
# 1     snoDB0002  ENSG00000252404          NaN         NaN          NaN
# 2     snoDB0003  ENSG00000239149  NR_003025.1  HGNC:32653     677885.0
# 3     snoDB0004  ENSG00000252969          NaN         NaN          NaN
# 4     snoDB0005  ENSG00000251866  NR_135613.1  HGNC:52237  107397391.0
# ...         ...              ...          ...         ...          ...
# 2118  snoDB2119              NaN          NaN         NaN          NaN
# 2119  snoDB2120              NaN          NaN         NaN          NaN
# 2120  snoDB2121              NaN          NaN         NaN          NaN
# 2121  snoDB2122              NaN          NaN         NaN          NaN
# 2122  snoDB2123              NaN          NaN         NaN          NaN
#
#      snornabase_id snorna_atlas_id            snopy_id  \
# 0              NaN             NaN  Homo_sapiens300648
# 1              NaN             NaN                 NaN
# 2        SR0000241      snoID_0545                 NaN
# 3              NaN             NaN                 NaN
# 4              NaN      snoID_0577                 NaN
# ...            ...             ...                 ...
# 2118           NaN             NaN                 NaN
# 2119           NaN             NaN                 NaN
# 2120           NaN             NaN                 NaN
# 2121           NaN             NaN                 NaN
# 2122           NaN             NaN                 NaN
#
#                    rna_central_id  rfam_id  ... snrna_targets lncrna_targets  \
# 0                   URS00006F7F32  RF00599  ...           NaN            NaN
# 1                   URS000066189C  RF00424  ...           NaN            NaN
# 2                   URS0000056589  RF01293  ...           NaN            NaN
# 3                   URS00006DED88  RF00156  ...           NaN            NaN
# 4     URS00006C4777;URS0000BC45E9  RF00602  ...      U12.1-18            NaN
# ...                           ...      ...  ...           ...            ...
# 2118                          NaN      NaN  ...           NaN            NaN
# 2119                          NaN      NaN  ...           NaN            NaN
# 2120                          NaN  RF01960  ...           NaN            NaN
# 2121                          NaN      NaN  ...           NaN            NaN
# 2122                          NaN      NaN  ...           NaN            NaN
#
#      protein_coding_targets  snorna_targets  mirna_targets trna_targets  \
# 0                       NaN             NaN            NaN          NaN
# 1                       NaN             NaN            NaN          NaN
# 2                       NaN             NaN            NaN          NaN
# 3                       NaN             NaN            NaN          NaN
# 4                       NaN             NaN            NaN          NaN
# ...                     ...             ...            ...          ...
# 2118                    NaN             NaN            NaN          NaN
# 2119                    NaN             NaN            NaN          NaN
# 2120                    NaN             NaN            NaN          NaN
# 2121                    NaN             NaN            NaN          NaN
# 2122                    NaN             NaN            NaN          NaN
#
#      ncrna_targets pseudogene_targets other_targets is_expressed
# 0              NaN                NaN           NaN        False
# 1              NaN                NaN           NaN        False
# 2              NaN                NaN           NaN         True
# 3              NaN                NaN           NaN        False
# 4              NaN                NaN           NaN         True
# ...            ...                ...           ...          ...
# 2118           NaN                NaN           NaN        False
# 2119           NaN                NaN           NaN        False
# 2120           NaN                NaN           NaN         True
# 2121           NaN                NaN           NaN        False
# 2122           NaN                NaN           NaN         True
#
# [2123 rows x 44 columns]

# %% [markdown]
# Then, this dataframe is combined with df2 (dataframe to which the column 'gene_name' was added). As a result, we have more detailed knowledge about the genes.

# %%
df2['gene_name']=df2['gene_name'].astype(str)
df4['gene_name']=df4['gene_name'].astype(str)

df5 = pd.merge(df2, df4, on='gene_name')

# %% [markdown]
# Finally, we create a csv file from the combined dataset, which comprises details about the snoRNAs from FANTOM5 and snoDB v.2.

# %%
df5.drop(['n4'], axis=1, inplace=True)
df5.to_csv("fantom_snodb.csv", index_label='id', encoding='utf-8')
